# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/ssn-29/anaconda3/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from pandas) (2.3.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import pandas as pd
df=pd.read_csv("english.csv")
print(df.head(5))
print(df.tail(5))
# Out:
#                 image label
# 0  Img/img001-001.png     0
# 1  Img/img001-002.png     0
# 2  Img/img001-003.png     0
# 3  Img/img001-004.png     0
# 4  Img/img001-005.png     0
#                    image label
# 3405  Img/img062-051.png     z
# 3406  Img/img062-052.png     z
# 3407  Img/img062-053.png     z
# 3408  Img/img062-054.png     z
# 3409  Img/img062-055.png     z

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /home/ssn-29/anaconda3/lib/python3.13/site-packages (4.13.0.90)
# Requirement already satisfied: numpy>=2 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from opencv-python) (2.3.5)

# %%
import cv2
import numpy as np
from sklearn.preprocessing import LabelEncoder
x=[]
y=[]

for _,row in df.iterrows():
    image=row['image']
    label=str(row['label'])
    img=cv2.imread(image,cv2.IMREAD_GRAYSCALE)
    resized_img=cv2.resize(img,(28,28))
    resized_img=resized_img/255.0
    resized_img=resized_img.flatten()
    x.append(resized_img)

    if(label=="z"):
        y.append(1)
    else:
        y.append(-1)
x=np.array(x)    
y=np.array(y)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score,f1_score,recall_score,precision_score,confusion_matrix,roc_curve,auc
class Perception:
    def __init__(self,lrate,epochs):
        self.lr=lrate
        self.epochs=epochs

    def step_function(self,z):
        return np.where(z>=0,1,-1)

    def fit(self,x,y):
        self.weights=np.zeros(x.shape[1])
        self.bias=0
        self.errors=[]

        for e in range(self.epochs):
            error_count=0
            for i in range(len(x)):
                z=np.dot(x[i],self.weights)+self.bias
                y_pred=self.step_function(z)

                if(y_pred!=y[i]):
                    self.weights+=self.lr*y[i]*x[i]
                    self.bias+=self.lr*y[i]
                    error_count+=1
            self.errors.append(error_count)
                    

    def predict(self,y_test):
         z=np.dot(y_test,self.weights)+self.bias
         return self.step_function(z)
    
        
pla=Perception(lrate=0.01,epochs=25)
pla.fit(x_train,y_train)
y_pred=pla.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print("Accuracy :", accuracy)
print("Precision:", precision)
print("Recall   :", recall)
print("F1-score :", f1)

cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)

plt.imshow(cm,cmap="Blues")
plt.title("CONFUSIN MATRIX")
plt.xlabel("Predicted_label")
plt.ylabel("True Labels")
plt.show()

scores=np.dot(x_test,pla.weights)+pla.bias
fpr,tpr,t=roc_curve(y_test,scores)
roc=auc(fpr,tpr)
plt.plot(fpr,tpr,label="ROC CURVE (AUC = %.2f)"%roc)
plt.plot([0, 1], [0, 1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

plt.plot(range(1,(len(pla.errors)+1)),pla.errors,marker='o')
plt.xlabel("Epochs")
plt.ylabel("Number of Misclassifications")
plt.title("Training Error vs Epochs")
plt.show()
# Out:
# Accuracy : 0.9853372434017595
# Precision: 0.0
# Recall   : 0.0
# F1-score : 0.0
# Confusion Matrix:
#  [[672   0]
#  [ 10   0]]
# /home/ssn-29/anaconda3/lib/python3.13/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 due to no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
pip install torch torchvision
# Out:
# Requirement already satisfied: torch in /home/ssn-29/anaconda3/lib/python3.13/site-packages (2.9.1)
# Requirement already satisfied: torchvision in /home/ssn-29/anaconda3/lib/python3.13/site-packages (0.24.1)
# Requirement already satisfied: filelock in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (4.12.2)
# Requirement already satisfied: setuptools in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (72.1.0)
# Requirement already satisfied: sympy>=1.13.3 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (1.13.3)
# Requirement already satisfied: networkx>=2.5.1 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (1.13.1.3)
# Requirement already satisfied: triton==3.5.1 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torch) (3.5.1)
# Requirement already satisfied: numpy in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torchvision) (2.3.5)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/ssn-29/anaconda3/lib/python3.13/site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader,TensorDataset 

le=LabelEncoder()
y_en=le.fit_transform(y)

learning_rate=[0.01,0.001]
batch_sizes=[32,64]
optimzers=["SDG","ADAM"]
activation=["Relu","Tanh"]
